# %% [markdown]
# # 01. Problem Definition
#
# ## Context
# Vietnamese agriculture, specifically Coffee and Rice, faces significant yield losses due to leaf diseases.
#
# ## Objective
# Develop an automated image classification system to help farmers diagnose diseases early using smartphone photos.
#
# ## Task
# - Multiclass classification of leaf images.
# - Target: Coffee (Healthy, Rust, Miner) & Rice (Healthy, Blast, Blight).
