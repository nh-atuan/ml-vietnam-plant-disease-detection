# %% [markdown]
# # 05. Model Evaluation
#
# ## Metrics
# - Accuracy, Precision, Recall, F1-Score.
# - Confusion Matrix visualization.
#
# ## Comparison
# Comparing Baseline vs. Intermediate vs. Advanced (ResNet).
