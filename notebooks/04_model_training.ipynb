# %% [markdown]
# # 04. Model Training
#
# In this notebook, we train our 3 models and compare performance.
#
# ```python
# from src.models.model_factory import BaselineCNN, AdvancedModel
# from src.pipeline.train_pipeline import train_model
# import torch.nn as nn
# import torch.optim as optim
# ```
#
# ## 1. Baseline Model
# Simple CNN to establish a performance floor.
#
# ## 2. Intermediate Model
# Custom CNN with Dropout and Batch Normalization.
#
# ## 3. Advanced Model
# ResNet-18 Transfer Learning (Fine-tuned).
