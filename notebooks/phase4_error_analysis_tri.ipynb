# %% [markdown]
# # Phase 4 Error Analysis\n\nPhụ trách: Lê Xuân Trí.\n\nMục tiêu: phân tích top-K dự đoán sai có confidence cao và nhóm lỗi theo visual similarity, chất lượng ảnh thấp, bố cục phức tạp, healthy vs early disease.
