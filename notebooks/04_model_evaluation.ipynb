# %% [markdown]
# # 04. Đánh giá Mô hình (Model Evaluation)
#
# ## Các chỉ số (Metrics)
# - Độ chính xác (Accuracy), Độ chuẩn xác (Precision), Độ bao phủ (Recall), Điểm F1 (F1-Score).
# - Biểu diễn ma trận nhầm lẫn (Confusion Matrix).
#
# ## So sánh (Comparison)
# So sánh hiệu năng giữa MobileNetV2, ResNet50 và các biến thể nâng cao (Swin Transformer / DINOv2).
