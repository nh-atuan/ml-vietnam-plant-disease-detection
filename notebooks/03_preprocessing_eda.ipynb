# %% [markdown]
# # 03. Preprocessing & EDA
#
# ## Tasks
# - Visualize class distribution.
# - Analyze image sizes and aspect ratios.
# - Apply data augmentation (rotation, flip, color jitter).
# - Standardize images to 224x224 for ResNet.
