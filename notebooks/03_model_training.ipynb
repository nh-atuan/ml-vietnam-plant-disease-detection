# %% [markdown]
# # 03. Huấn luyện Mô hình (Model Training)
#
# Trong notebook này, chúng ta sẽ huấn luyện 3 mô hình và so sánh hiệu suất cũng như theo dõi qua MLflow.

# %%
from src.models.model_factory import BaselineCNN, AdvancedModel
from src.pipeline.train_pipeline import train_model
import torch.nn as nn
import torch.optim as optim

# %% [markdown]
# ## 1. Mô hình MobileNetV2 (Baseline)
# Mô hình CNN nhẹ dùng làm cơ sở đánh giá ban đầu.
#
# ## 2. Mô hình ResNet50
# Mô hình CNN mạnh với kĩ thuật Transfer Learning.
#
# ## 3. Mô hình Swin Transformer / DINOv2
# Mô hình tiên tiến (Vision Transformer hoặc Self-supervised) với backbone mạnh.
