# %% [markdown]
# # Phase 4 Robustness Evaluation\n\nPhụ trách: Nguyễn Hồ Anh Tuấn.\n\nMục tiêu: tạo test set nhiễu tổng hợp bằng blur, brightness shift và contrast change, sau đó đo mức giảm Macro F1 theo từng mức nhiễu.
